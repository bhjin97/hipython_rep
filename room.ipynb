# %%
import pandas as pd
df=pd.read_csv('./data/방탈출 데이터.csv')
df
# Out:
#       지역                  매장              테마     별점  난이도  리뷰수
# 0     신촌  이스케이프시티 그랜드 시티 신촌점            컨티뉴얼  10.00    0    1
# 1     부산        셜록홈즈 부산아트몰링점          시간의 회랑  10.00    0    1
# 2     강남       키이스케이프 메모리컴퍼니     FILM BY BOB   9.62    4  406
# 3     강남       키이스케이프 메모리컴퍼니   FILM BY STEVE   9.59    6  777
# 4     건대             드림이스케이프     바야흐로, 여름이었다   9.57    5  282
# ...   ..                 ...             ...    ...  ...  ...
# 1839  울산          이스케이프탑 울산점  프리즌 : 수감번호1508   0.00    0    2
# 1840  울산          이스케이프탑 울산점       미션 : 폭탄제거   0.00    0    2
# 1841  창원          이스케이프탑 창원점  프리즌 : 수감번호1508   0.00    0    2
# 1842  창원          이스케이프탑 창원점       미션 : 폭탄제거   0.00    0    3
# 1843  강원            셜록홈즈 강릉점      이상한 나라의 초대   0.00    0    5
#
# [1844 rows x 6 columns]

# %%
df1=df[df['지역']=='강남']
df2=df1[df1['별점']>=9.00]
df3=df2.reset_index(drop=True)
df4=df3[df3['난이도']<=6.00]
df4.reset_index(drop=True)
# Out:
#     지역                매장                     테마    별점  난이도  리뷰수
# 0   강남     키이스케이프 메모리컴퍼니            FILM BY BOB  9.62    4  406
# 1   강남     키이스케이프 메모리컴퍼니          FILM BY STEVE  9.59    6  777
# 2   강남   키이스케이프 LOG_IN 1                머니머니패키지  9.53    6  625
# 3   강남     키이스케이프 메모리컴퍼니           FILM BY EDDY  9.46    4  790
# 4   강남   키이스케이프 LOG_IN 1               FOR FREE  9.32    4  229
# 5   강남   키이스케이프 LOG_IN 2     BACK TO THE SCENE+  9.32    4  543
# 6   강남               단편선              그림자 없는 상자  9.30    4  867
# 7   강남  키이스케이프 강남 우주라이크점          WANNA GO HOME  9.23    6  843
# 8   강남               단편선  사람들은 그것을 행복이라 부르기로 했다  9.22    6  805
# 9   강남    키이스케이프 강남 더오름점                     네드  9.22    6  951
# 10  강남  키이스케이프 강남 우주라이크점                     US  9.20    6  896
# 11  강남          제로월드 강남점                      링  9.09    5  756
# 12  강남        비트포비아 던전루나               검은 운명의 밤  9.08    5  490
# 13  강남          제로월드 강남점                   DONE  9.00    6  730
