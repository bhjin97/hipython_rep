# %%
import requests
url = 'https://httpbin.org/get'

response = requests.get(url)

response.status_code
print(response.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68870e69-48029f602b546baa088825b7"
#   },
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/get"
# }

# %%
params = {
    'name': 'bae',
    'age': '20'
     }

url = 'https://httpbin.org/get'

response = requests.get(url, params=params)

response.status_code
print(response.text)
# Out:
# {
#   "args": {
#     "age": "20",
#     "name": "bae"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68870e63-1ad430245f6777694c905f60"
#   },
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/get?name=bae&age=20"
# }

# %%
url = 'https://httpbin.org/post'

response = requests.post(url, json={'key':'value'})

response.status_code
print(response.text)
# Out:
# {
#   "args": {},
#   "data": "{\"key\": \"value\"}",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "16",
#     "Content-Type": "application/json",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-688710e8-5ee8627d3c4918257f1b2dff"
#   },
#   "json": {
#     "key": "value"
#   },
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/post"
# }

# %%
response.json()['headers']['Content-Type']
# Out:
# 'application/x-www-form-urlencoded'

# %%
response.json()['headers']['User-Agent']
# Out:
# 'python-requests/2.32.4'

# %%
response1 = requests.put('https://httpbin.org/put', data={'key':'value'})
print(response1.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6887108e-262b5ad22e95e3586632499f"
#   },
#   "json": null,
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/put"
# }

# %%
response2 = requests.patch('https://httpbin.org/patch', data={'key':'value'})
print(response2.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-688710af-42d08103699b3fe250a43341"
#   },
#   "json": null,
#   "origin": "118.36.174.103",
#   "url": "https://httpbin.org/patch"
# }
