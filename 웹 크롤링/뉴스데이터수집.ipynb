# %%
#container > div > div > div:nth-child(2) > ul > li:nth-child(2) > a.rss_link
//*[@id="container"]/div/div/div[2]/ul/li[2]/a[1]

# %%
import requests
from bs4 import BeautifulSoup
news_rss = requests.get('https://news.sbs.co.kr/news/TopicRssFeed.do?plink=RSSREADER')
news_rss_soup = BeautifulSoup(news_rss.content, 'xml')
link_list = news_rss_soup.select('item link')
print("기사 개수:", len(link_list))
# Out:
# 기사 개수: 9

# %%
title_list = [title.text for title in link_list]
title_list
# Out:
# ['https://news.sbs.co.kr/news/endPage.do?news_id=N1008195901&plink=RSSLINK&cooper=RSSREADER',
#  'https://news.sbs.co.kr/news/endPage.do?news_id=N1008196114&plink=RSSLINK&cooper=RSSREADER',
#  'https://news.sbs.co.kr/news/endPage.do?news_id=N1008195907&plink=RSSLINK&cooper=RSSREADER',
#  'https://news.sbs.co.kr/news/endPage.do?news_id=N1008195905&plink=RSSLINK&cooper=RSSREADER',
#  'https://news.sbs.co.kr/news/endPage.do?news_id=N1008195903&plink=RSSLINK&cooper=RSSREADER',
#  'https://news.sbs.co.kr/news/endPage.do?news_id=N1008195898&plink=RSSLINK&cooper=RSSREADER',
#  'https://news.sbs.co.kr/news/endPage.do?news_id=N1008196003&plink=RSSLINK&cooper=RSSREADER',
#  'https://news.sbs.co.kr/news/endPage.do?news_id=N1008195970&plink=RSSLINK&cooper=RSSREADER',
#  'https://news.sbs.co.kr/news/endPage.do?news_id=N1008195773&plink=RSSLINK&cooper=RSSREADER']

# %%
news_data = []

for link in link_list:
    news_response = requests.get(link.text)
    news_content_soup = BeautifulSoup(news_response.content, 'html.parser')
    news_content = news_content_soup.select_one("div[itemprop=articleBody]")
    news_data.append(news_content)

import pandas as pd
news_df = pd.DataFrame(data={'title': title_list, 'content': news_data})
news_df.to_csv("news.csv", encoding="utf-8-sig", index=False)
print("Save complete")
# Out:
# Save complete
